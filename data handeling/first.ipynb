# %%
import pandas as pd
import xlrd

# %%
df = pd.read_excel("sampledatafoodsales.xlsx", "FoodSales")

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
r,c = df.shape

# %%
print(r)
# Out:
# 244

# %%
df.head() #to show the first 5 data
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0 2020-01-01   East       Boston      Bars          Carrot        33
# 1 2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2 2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3 2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4 2020-01-13   East       Boston   Cookies       Arrowroot        38
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84

# %%
df.tail() #to show the last 5 data
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 239       2.18       74.12
# 240       1.87      458.15
# 241       3.49      104.70
# 242       1.87       56.10
# 243       2.84      124.96

# %%
df.head(17)
# Out:
#     OrderDate Region         City  Category         Product  Quantity  \
# 0  2020-01-01   East       Boston      Bars          Carrot        33
# 1  2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2  2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3  2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4  2020-01-13   East       Boston   Cookies       Arrowroot        38
# 5  2020-01-16   East       Boston      Bars          Carrot        54
# 6  2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 7  2020-01-22   West  Los Angeles      Bars          Carrot        51
# 8  2020-01-25   East     New York      Bars          Carrot       100
# 9  2020-01-28   East     New York    Snacks    Potato Chips        28
# 10 2020-01-31   East       Boston   Cookies       Arrowroot        36
# 11 2020-02-03   East       Boston   Cookies  Chocolate Chip        31
# ...

# %%
df[85:144]
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 85  2020-09-13   East       Boston    Snacks        Pretzels        27
# 86  2020-09-16   West  Los Angeles      Bars          Carrot       133
# 87  2020-09-19   East     New York   Cookies       Arrowroot       110
# 88  2020-09-22   East     New York   Cookies  Chocolate Chip        65
# 89  2020-09-25   West    San Diego      Bars            Bran        33
# 90  2020-09-28   East       Boston   Cookies       Arrowroot        81
# 91  2020-10-01   East       Boston      Bars          Carrot        77
# 92  2020-10-04   East       Boston  Crackers     Whole Wheat        38
# 93  2020-10-07   West  Los Angeles      Bars          Carrot        40
# 94  2020-10-10   West  Los Angeles    Snacks    Potato Chips       114
# 95  2020-10-13   East     New York   Cookies       Arrowroot       224
# 96  2020-10-16   East     New York      Bars          Carrot       141
# ...

# %%
df[0::2] #to show the alternate data
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# 6   2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 8   2020-01-25   East     New York      Bars          Carrot       100
# ..         ...    ...          ...       ...             ...       ...
# 234 2021-12-03   West  Los Angeles      Bars            Bran        42
# 236 2021-12-09   East     New York      Bars          Carrot        38
# 238 2021-12-15   West    San Diego   Cookies  Chocolate Chip        96
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 2         1.87      108.46
# 4         2.18       82.84
# ...

# %%
df[5:0:-1]
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 5 2020-01-16   East       Boston      Bars          Carrot        54
# 4 2020-01-13   East       Boston   Cookies       Arrowroot        38
# 3 2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 2 2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 1 2020-01-04   East       Boston  Crackers     Whole Wheat        87
#
#    UnitPrice  TotalPrice
# 5       1.77       95.58
# 4       2.18       82.84
# 3       1.87      153.34
# 2       1.87      108.46
# 1       3.49      303.63

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'City', 'Category', 'Product', 'Quantity',
#        'UnitPrice', 'TotalPrice'],
#       dtype='object')

# %%
df.TotalPrice
# Out:
# 0       58.41
# 1      303.63
# 2      108.46
# 3      153.34
# 4       82.84
#         ...
# 239     74.12
# 240    458.15
# 241    104.70
# 242     56.10
# 243    124.96
# Name: TotalPrice, Length: 244, dtype: float64

# %%
df[['OrderDate', 'Region']]
# Out:
#      OrderDate Region
# 0   2020-01-01   East
# 1   2020-01-04   East
# 2   2020-01-07   West
# 3   2020-01-10   East
# 4   2020-01-13   East
# ..         ...    ...
# 239 2021-12-18   East
# 240 2021-12-21   East
# 241 2021-12-24   East
# 242 2021-12-27   West
# 243 2021-12-30   West
#
# [244 rows x 2 columns]

# %%
df.describe()
# Out:
#          Quantity   UnitPrice  TotalPrice
# count  244.000000  244.000000  244.000000
# mean    63.286885    2.200820  136.580246
# std     47.112505    0.600169  108.354231
# min     20.000000    1.350000   33.600000
# 25%     31.000000    1.770000   72.570000
# 50%     47.000000    1.870000  102.755000
# 75%     80.000000    2.840000  159.300000
# max    306.000000    3.490000  817.920000

# %%
df[df.TotalPrice > 200] # the data where totalprice > 100
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 6   2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 17  2020-02-21   East       Boston   Cookies  Oatmeal Raisin       123
# 29  2020-03-29   East       Boston   Cookies  Oatmeal Raisin       193
# 36  2020-04-19   East       Boston    Snacks    Potato Chips       134
# 42  2020-05-07   East       Boston   Cookies  Oatmeal Raisin       138
# 51  2020-06-03   West  Los Angeles   Cookies  Oatmeal Raisin       288
# 57  2020-06-21   West  Los Angeles      Bars          Carrot       306
# 59  2020-06-27   East     New York      Bars            Bran       110
# 63  2020-07-09   East       Boston      Bars          Carrot       136
# 71  2020-08-02   East       Boston   Cookies  Oatmeal Raisin       137
# 72  2020-08-05   West  Los Angeles   Cookies  Chocolate Chip       107
# ...

# %%
df[['OrderDate', 'TotalPrice', 'Region']][df.TotalPrice > 200]
# Out:
#      OrderDate  TotalPrice Region
# 1   2020-01-04      303.63   East
# 6   2020-01-19      520.01   East
# 17  2020-02-21      349.32   East
# 29  2020-03-29      548.12   East
# 36  2020-04-19      225.12   East
# 42  2020-05-07      391.92   East
# 51  2020-06-03      817.92   West
# 57  2020-06-21      541.62   West
# 59  2020-06-27      205.70   East
# 63  2020-07-09      240.72   East
# 71  2020-08-02      389.08   East
# 72  2020-08-05      200.09   West
# 81  2020-09-01      210.16   East
# 84  2020-09-10      253.11   East
# 86  2020-09-16      235.41   West
# 87  2020-09-19      239.80   East
# 95  2020-10-13      488.32   East
# 96  2020-10-16      249.57   East
# 105 2020-11-12      224.54   West
# 108 2020-11-21      275.48   East
# 112 2020-12-03      303.02   West
# 119 2020-12-24      516.66   East
# 126 2021-01-14      227.20   West
# 141 2021-02-28      433.84   West
# 143 2021-03-05      275.48   East
# 152 2021-04-01      208.86   West
# ...

# %%
df1 = df.sort_values('TotalPrice', ascending=False)
df1
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 51  2020-06-03   West  Los Angeles   Cookies  Oatmeal Raisin       288
# 29  2020-03-29   East       Boston   Cookies  Oatmeal Raisin       193
# 57  2020-06-21   West  Los Angeles      Bars          Carrot       306
# 6   2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 119 2020-12-24   East     New York   Cookies       Arrowroot       237
# ..         ...    ...          ...       ...             ...       ...
# 230 2021-11-21   West    San Diego      Bars          Carrot        20
# 37  2020-04-22   West  Los Angeles      Bars          Carrot        20
# 98  2020-10-22   West    San Diego      Bars          Carrot        20
# 136 2021-02-13   East     New York    Snacks    Potato Chips        21
# 208 2021-09-16   East     New York    Snacks    Potato Chips        20
#
#      UnitPrice  TotalPrice
# 51        2.84      817.92
# 29        2.84      548.12
# 57        1.77      541.62
# ...

# %%
df1 = df.sort_values(by=['TotalPrice', 'UnitPrice'], ascending=[False, True])
df1
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 51  2020-06-03   West  Los Angeles   Cookies  Oatmeal Raisin       288
# 29  2020-03-29   East       Boston   Cookies  Oatmeal Raisin       193
# 57  2020-06-21   West  Los Angeles      Bars          Carrot       306
# 6   2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 119 2020-12-24   East     New York   Cookies       Arrowroot       237
# ..         ...    ...          ...       ...             ...       ...
# 37  2020-04-22   West  Los Angeles      Bars          Carrot        20
# 98  2020-10-22   West    San Diego      Bars          Carrot        20
# 230 2021-11-21   West    San Diego      Bars          Carrot        20
# 136 2021-02-13   East     New York    Snacks    Potato Chips        21
# 208 2021-09-16   East     New York    Snacks    Potato Chips        20
#
#      UnitPrice  TotalPrice
# 51        2.84      817.92
# 29        2.84      548.12
# 57        1.77      541.62
# ...

# %%
df2 = pd.read_excel("sample.xlsx")
# Out:
# C:\Program Files\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df2
# Out:
#                  Title Identifier            Date  \
# 0             My Title   2016.1.1         6/16/16
# 1        Another title   2016.1.2  January 4 1965
# 2  The best image ever   2015.4.5         12/1/93
#
#                                Subject  \
# 0                       Farm subsidies
# 1  The Who; British Invasion; AM radio
# 2                Politics; Memes; Cats
#
#                                  Description                   Notes  \
# 0               This is a sample description              some notes
# 1  Eloquently written curatorial description  notes for internal use
# 2                                        NaN                     NaN
#
#         Creator          Accession  Accession No Reproduction
# 0      John Doe  Gift of So and So        2016.1         orig
# 1      John Doe  Gift of So and So        2016.1          NaN
# 2  Mary Maryson    Some other Gift        2015.4          NaN

# %%
df2.fillna(0)
# Out:
#                  Title Identifier            Date  \
# 0             My Title   2016.1.1         6/16/16
# 1        Another title   2016.1.2  January 4 1965
# 2  The best image ever   2015.4.5         12/1/93
#
#                                Subject  \
# 0                       Farm subsidies
# 1  The Who; British Invasion; AM radio
# 2                Politics; Memes; Cats
#
#                                  Description                   Notes  \
# 0               This is a sample description              some notes
# 1  Eloquently written curatorial description  notes for internal use
# 2                                          0                       0
#
#         Creator          Accession  Accession No Reproduction
# 0      John Doe  Gift of So and So        2016.1         orig
# 1      John Doe  Gift of So and So        2016.1            0
# 2  Mary Maryson    Some other Gift        2015.4            0

# %%
df2.dropna()
# Out:
#       Title Identifier     Date         Subject                   Description  \
# 0  My Title   2016.1.1  6/16/16  Farm subsidies  This is a sample description
#
#         Notes   Creator          Accession  Accession No Reproduction
# 0  some notes  John Doe  Gift of So and So        2016.1         orig

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
age = [22,45,30,59,58,56,57,45,43,43,43,50,40,34,33,25,19]

# %%
bin = [0,10,20,30,40,50,60,70]

# %%
plt.hist(age, bin, histtype='bar', rwidth=0.8, color="red")
plt.xlabel("Ege of Employee")
plt.ylabel("No of Employee")
plt.title("Our first graph")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
slices = [50,20,15,15]
dept = ["Sales", "Production", "HR", "Finance"]
clr = ["magenta", "cyan", "brown", "red"]

# %%
plt.pie(slices, labels=dept, colors=clr, shadow=True, startangle=90, explode=(0,0,0.2,0))

plt.show()  #!!!! to the graph

# %%
import json
data = urllib2.urlopen('url')
data = data.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0e0307741deb> in <module>
#       1 import json
# ----> 2 data = urllib2.urlopen('url')
#       3 data = data.read()
#
# NameError: name 'urllib2' is not defined

# %%
jsdata= json.loads()
